# %%
from p4p.client.thread import Context

# os.environ["EPICS_PVA_NAME_SERVERS"] = "172.24.5.147:5075" # check its live on s3d
# server

import numpy as np

ctxt = Context('pva')
from matplotlib import pyplot as plt

# %%
arry = ctxt.put('LUME:MLFLOW:TEST_B', np.random.rand(56, 1) * 0.1)
arry_img = ctxt.get('OUTPUT_IMAGE')
plt.imshow(arry_img)
plt.show()
