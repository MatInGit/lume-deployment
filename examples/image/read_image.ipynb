# %%
# !pip install ipympl
# %matplotlib ipympl
from p4p.client.thread import Context
import os 
os.environ["EPICS_PVA_NAME_SERVERS"] = "172.24.5.147:5075" # check its live on s3d
# server
from p4p.server import Server
from p4p.nt import NTScalar, NTNDArray
from p4p.server.thread import SharedPV

import numpy as np
ctxt = Context("pva")
from matplotlib import pyplot as plt
# Out:
# 2024-05-02T15:17:50.509850156 ERR pvxs.tcp.io connection to Server 172.24.5.147:5075 closed with socket error 111 : Connection refused

# %%
arry = ctxt.get("LUME:MLFLOW:TEST_IMAGE")

plt.imshow(arry)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
